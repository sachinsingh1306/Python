# %%
# Write a program to create a dictionary of hindi words with english translation?
words = {"Bili":"Cat",
        "Kursi":"Chair",
        "Sev":"Apple",
        "aam":"Mango"}
word = input("Enter a Word : ")
meaning = ("In English it is : ")
print(meaning, words[word])
# Out:
# Enter a Word :  Kursi
# In English it is :  Chair

# %%
# Write a program to input 8 number from user to display unique number once?
number = set()

num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))
num = input("Enter a number :")
number.add(int(num))

print(number)
# Out:
# Enter a number : 1
# Enter a number : 5
# Enter a number : 5
# Enter a number : 54
# Enter a number : 4
# Enter a number : 4
# Enter a number : 47
# Enter a number : 4
# {1, 4, 5, 47, 54}

# %%
# Can we have the set with 18 (int) and '18' (str) as a value ?
# Yes
set = {18, "18"}
print(set)
# Out:
# {18, '18'}

# %%
# What is the lenght of the set ?
s = set()
s.add(20)
s.add(20.0)
s.add("20")

print(s)
print(len(s))

# %%
# What is the type of s={}?
s = {}
print(type(s))
# Out:
# <class 'dict'>

# %%
# Create a empty dictionary. Allow 4 friends to enter their favorite language and the values and  keys as their name?
list = {}
print(list)
name = input("enter your name :")
lang = input("enter your language :")
list.update({name:lang})
name = input("enter your name :")
lang = input("enter your language :")
list.update({name:lang})
name = input("enter your name :")
lang = input("enter your language :")
list.update({name:lang})
name = input("enter your name :")
lang = input("enter your language :")
list.update({name:lang})

print(list)
# Out:
# {}
# enter your name : alok
# enter your language : react.js
# enter your name : teza
# enter your language : java
# enter your name : aditya
# enter your language : python,c++
# enter your name : sachin
# enter your language : python
# {'alok': 'react.js', 'teza': 'java', 'aditya': 'python,c++', 'sachin': 'python'}

# %%
# Write a program to ask the user for their name and print a greeting message.
name = input("Enter your name : ")
greet = (f"Good Morning ! {name}. How are you?")
print(greet)
# Out:
# Enter your name :  Alok
# Good Morning ! Alok. How are you?

# %%
# Take two numbers as input and print their sum.
num1 = int(input("enter number 1 : "))
num2 = int(input("enter number 2 : "))
sum = (num1 + num2)
print("Sum of num1 & num2 is:",sum)
# Out:
# enter number 1 :  12
# enter number 2 :  12
# Sum of num1 & num2 is: 24

# %%
# Take two numbers as input and print their difference.
num1 = int(input("enter number 1 : "))
num2 = int(input("enter number 2 : "))
diff = (num1 - num2)
print("Difference of num1 & num2 is:",diff)
# Out:
# enter number 1 :  12
# enter number 2 :  6
# Difference of num1 & num2 is: 6

# %%
# Take two numbers as input and print their product.
num1 = int(input("enter number 1 : "))
num2 = int(input("enter number 2 : "))
product = (num1 * num2)
print("Product of num1 & num2 is:",product)
# Out:
# enter number 1 :  12
# enter number 2 :  2
# Product of num1 & num2 is: 24

# %%
# Take two numbers as input and print their division result.
num1 = int(input("enter number 1 : "))
num2 = int(input("enter number 2 : "))
division = (num1 / num2)
print("Division of num1 & num2 is:",division)
# Out:
# enter number 1 :  12
# enter number 2 :  6
# Division of num1 & num2 is: 2.0

# %%
# Ask the user for a number and print its square.
num = int(input("enter number : "))
square = (num *num)
print(f"Square of the {num} is : {square}")
# Out:
# enter number :  12
# Square of the 12 is : 144

# %%
# Ask the user for their age and print:
# "You are <age> years old!"
user = int(input("enter your birth year : "))
age = ( 2025 - user)
print(f"You are {age} year old!")
# Out:
# enter your birth year :  2002
# You are 23 year old!

# %%
# Input two numbers and print:
# "The first number is bigger" or "The second number is bigger"
num1 = int(input("enter number 1 : "))
num2 = int(input("enter number 2 : "))
if num1 > num2 :
  print("The frist number is bigger")
elif num2 > num1:
    print("The second number is bigger")
else:
    print("Both number are equale")
# Out:
# enter number 1 :  12
# enter number 2 :  144
# The second number is bigger

# %%
# Ask the user for a number and print whether it is positive, negative, or zero.
num = int(input("enter number : "))
if num >0:
    print(f"{num} is Positive")
elif num < 0:
    print(f"{num} is Negative")
else:
    print(f"{num} is Zero")
# Out:
# enter number :  0
# 0 is Zero

# %%
# Ask the user for 3 numbers and print their total sum.
num1 = int(input("enter number 1 : "))
num2 = int(input("enter number 2 : "))
num3 = int(input("enter number 3 : "))
total = (num1 + num2 + num3)
print("total of all 3 number is : ", total)
# Out:
# enter number 1 :  1
# enter number 2 :  1
# enter number 3 :  1
# total of all 3 number is :  3

# %%
# Ask the user for a number and print whether it is EVEN or ODD.
number = int(input("Enter a number : "))
if number % 2 == 0:
    print(f"{number} is a Even")
else:
    print(f"{number} is a Odd")
# Out:
# Enter a number :  5
# 5 is a Odd

# %%
# Ask the user to enter 5 numbers. Store them in a list.
# Then print the largest number from the list.

numbers = []

num1 = int(input("enter number 1 : "))
numbers.append(num1)

num2 = int(input("enter number 2 : "))
numbers.append(num2)

num3 = int(input("enter number 3 : "))
numbers.append(num3)

num4 = int(input("enter number 4 : "))
numbers.append(num4)

num5 = int(input("enter number 5 : "))
numbers.append(num5)

numbers.sort()
print("Largest number is :", numbers[-1])
# Out:
# enter number 1 :  12
# enter number 2 :  45
# enter number 3 :  78
# enter number 4 :  4569
# enter number 5 :  52
# Largest number is : 4569

# %%
# Ask the user to enter 5 numbers.
# Store them in a list.
# Then print the smallest number from the list.
numbers = []

num1 = int(input("enter number 1 : "))
numbers.append(num1)

num2 = int(input("enter number 2 : "))
numbers.append(num2)

num3 = int(input("enter number 3 : "))
numbers.append(num3)

num4 = int(input("enter number 4 : "))
numbers.append(num4)

num5 = int(input("enter number 5 : "))
numbers.append(num5)

numbers.sort()
print("Smallest number is :", numbers[0])
# Out:
# enter number 1 :  12
# enter number 2 :  45
# enter number 3 :  547
# enter number 4 :  1
# enter number 5 :  0
# Largest number is : 0
