# %%
# Write a program to find the greatest of the 3 number.
              
a = int(input("Enter a number :"))
b = int(input("Enter a number :"))
c = int(input("Enter a number :"))
def greatest(a,b,c):
    if(a>b and a>c):
        return a
    elif(b>a and b>c):
        return b
    elif(c>a and c>b):
        return c
    elif(a==b and b==c):
       return("All are Equale")
print(greatest(a,b,c), "is greater than in 3 numbers.")
# Out:
# Enter a number : 54
# Enter a number : 47
# Enter a number : 48
# 54 is greater than in 3 numbers.

# %%
# Write a program to convert the celsius to fahrenheit.
celsius = int(input("Enter a Temperature :"))
def f_to_c(celsius):
    return ((celsius*1.8)+32)
f = f_to_c(c)
print(f"{celsius}°C equales to {f} Fahrenheit")
# Out:
# Enter a Temperature : 45
# 45°C equales to 118.4 fahrenheit

# %%
# How do you prevent the python print() function to print newline at the end.
print("Hello")
print("World")
print("Hello", end=" ")
print("World")
print("Sachin", end=' ')
print("Singh")
# Out:
# Hello
# World
# Hello World
# Sachin Singh

# %%
# Write the function to calculate the sum of frist n natural number.
def sum_of_numbers(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total

n = int(input("Enter a number: "))
print(sum_of_numbers(n))
# Out:
# Enter a number:  5
# 15
