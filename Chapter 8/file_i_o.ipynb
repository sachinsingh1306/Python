# %%
# Write a program to read and the text from a given file poems.txt and out wheather it contains the word Sachin

f = open("frist.txt", "w")
f.write("Sachin Singh")
f.close()

# %%
# Read the Txt file
# f = open("frist.txt", "r")
# content = f.read()
# print(content)
# f.close()

with open("frist.txt" ,"r") as f:
    content = f.read()
    print(content)
    if("Sachin" in content):
        print("Yes")
    else:
        print("No")
# Out:
# Sachin Singh
# Yes
